# %% [markdown]
# # Stack Overflow Sample Data
#
# The data has been turned from XML to Parquet format in [`code/stackoverflow/xml_to_parquet.py`](/edit/stackoverflow/sample_json.spark.py) and then 100K questions and their associated records were sampled in [`code/stackoverflow/sample_json.spark.py`](/edit/stackoverflow/sample_json.spark.py).
#
# The records are in [`data/stackoverflow/sample`](/tree/data/stackoverflow/sample):
#
# ## `Badges.100K.Questions.jsonl.gz`:
#
# ```json
# {"_Class":3,"_Date":"2008-09-15T08:55:03.957","_Id":82947,"_Name":"Teacher","_TagBased":false,"_UserId":994}
# {"_Class":3,"_Date":"2008-09-15T08:55:03.957","_Id":82953,"_Name":"Teacher","_TagBased":false,"_UserId":1113}
# {"_Class":3,"_Date":"2008-09-15T08:55:03.957","_Id":82957,"_Name":"Teacher","_TagBased":false,"_UserId":5246}
# ```
#
# ## `Comments.100K.Questions.jsonl.gz`:
#
# ```json
# {"_CreationDate":"2008-09-07T00:18:11.643","_Id":61,"_PostId":47960,"_Score":2,"_Text":"You're really going to have to be more specific...\n\nAre you looking for websites that contain web snippets and tutorials? Code snippets themselves on a particular topic? This is a very, very general question.","_UserId":2658}
# {"_CreationDate":"2008-09-07T00:37:17.870","_Id":63,"_PostId":47960,"_Score":0,"_Text":"Have you even used any code snippets?\nThere is no \"best\" code snippets.  There are snippets that are more \"useful\" than others, but no \"best\" snippets.  I wish i can edit the title...","_UserId":4035}
# {"_CreationDate":"2008-09-07T23:09:03.410","_Id":193,"_PostId":47177,"_Score":0,"_Text":"To clarify, the sigar api gets you system info. If you want jvm info use JMX.","_UserId":828}
# ```
#
# ## `PostHistory.100K.Questions.jsonl.gz`:
#
# ```json
# {"_CreationDate":"2008-08-07T20:24:34.003","_Id":6190,"_PostHistoryTypeId":1,"_PostId":5264,"_RevisionGUID":"c19e5ea1-2b11-4c54-91ba-d233afb81026","_Text":"How can I dynamically center an image in a MS Reporting Services report?","_UserId":326}
# {"_CreationDate":"2008-08-07T20:24:34.003","_Id":6191,"_PostHistoryTypeId":3,"_PostId":5264,"_RevisionGUID":"c19e5ea1-2b11-4c54-91ba-d233afb81026","_Text":"<reporting-services>","_UserId":326}
# {"_CreationDate":"2008-08-07T20:24:34.003","_Id":6192,"_PostHistoryTypeId":2,"_PostId":5264,"_RevisionGUID":"c19e5ea1-2b11-4c54-91ba-d233afb81026","_Text":"Out of the box, in MS Reporting Services, the image element does not allow for the centering of the image itself, when the dimensions are unknown at design time. In other words, the image (if smaller than the dimensions allotted on the design surface) will be anchored to the top left corner, not in the center.\r\n\r\nMy report will know the URL of the image at runtime, and I need to be able to center this image if it is smaller than the dimensions specified in my designer.","_UserId":326}
# ```
#
# ## `Posts.100K.Questions.jsonl.gz`:
#
# ```json
# {"_AcceptedAnswerId":4877,"_AnswerCount":2,"_Body":"<p>My dream IDE does full code hints, explains and completes PHP, Javascript, HTML and CSS. I know it exists!</p>\n\n<p>so far, <a href=\"http://www.zend.com/en/products/studio/features\" rel=\"noreferrer\">Zend studio 6</a>, under the Eclipse IDE does a great job at hinting PHP, some Javascript and HTML, any way I can expand this?</p>\n\n<p>edit: a bit more information: right now, using zend-6 under eclipse, i type in</p>\n\n<pre><code>&lt;?php\np //(a single letter \"p\")\n</code></pre>\n\n<p>and I get a hint tooltip with all the available php functions that begin with \"p\" (phpinfo(), parse_ini_file(), parse_str(), etc...), each with its own explanation: phpinfo()->\"outputs lots of PHP information\", the same applies for regular HTML (no explanations however).</p>\n\n<p>However, I get nothing when I do:</p>\n\n<pre><code>&lt;style&gt;\nb /* (a single letter \"b\") */\n</code></pre>\n\n<p>I'd love it if I could get, from that \"b\" suggestions for \"border\", \"bottom\", etc. The same applies for Javascript.</p>\n\n<p>Any ideas?</p>\n","_CommentCount":0,"_CreationDate":"2008-08-07T15:12:10.530","_Id":4839,"_LastActivityDate":"2013-02-12T11:55:21.800","_LastEditDate":"2013-02-12T11:55:21.800","_LastEditorDisplayName":"mauriciopastrana","_LastEditorUserId":1201415,"_OwnerUserId":547,"_PostTypeId":1,"_Score":7,"_Tags":"<zend-studio><code-completion>","_Title":"How do I configure eclipse (zend studio 6) to hint and code complete several languages?","_ViewCount":3275}
# {"_AcceptedAnswerId":5224,"_AnswerCount":5,"_Body":"<p>What is the Java equivalent of PHP's <code>$_POST</code>? After searching the web for an hour, I'm still nowhere closer.</p>\n","_CommentCount":0,"_CreationDate":"2008-08-07T19:39:31.240","_FavoriteCount":10,"_Id":5222,"_LastActivityDate":"2018-04-19T13:12:43.453","_LastEditDate":"2015-07-25T13:10:57.280","_LastEditorDisplayName":"Stu Thompson","_LastEditorUserId":507738,"_OwnerUserId":429,"_PostTypeId":1,"_Score":51,"_Tags":"<java><http><servlets>","_Title":"Accessing post variables using Java Servlets","_ViewCount":113478}
# {"_AcceptedAnswerId":5462,"_AnswerCount":8,"_Body":"<p>The company I work for is wanting to add blog functionality to our website and they were looking to spend an awful amount of money to have some crap being built on top of a CMS they purchased (sitecore).  I pointed them to Telligent's Community Server and  we had a sales like meeting today to get the Marketing folks on board. \nMy question is if anyone has had issues working with Community Server, skinning it and extending it?<br />\nI wanted to explain a bit why I am thinking Community Server, the company is wanting multiple blogs with multiple authors.  I want to be out of the admin part of this as much as possible and didn't think there were too many engines that having multiple blogs didn't mean db work.  I also like the other functionality that Community Server provides and think the company will find it useful, particularly the media section as right now we have some really shotty way of dealing with whitepapers and stuff.</p>\n\n<p>edit: We are actually using the Sitecore blog module for a single blog on our intranet (which is actually what the CMS is serving).  Some reasoning for why I don't like it for our public site are they are on different servers, it doesn't support multiple authors, there is no built in syndication, it is a little flimsy feeling to me from looking at the source and I personally think the other features of Community Server make its price tag worth it.</p>\n\n<p>another edit: Need to stick to .net software that run on sql server in my company's case, but I don't mind seeing recommendations for others.  ExpressionEngine looks promising, will try it out on my personal box.</p>\n","_ClosedDate":"2012-11-16T12:21:26.777","_CommentCount":0,"_CreationDate":"2008-08-07T23:00:30.053","_Id":5460,"_LastActivityDate":"2011-05-05T02:37:41.240","_LastEditDate":"2008-08-08T00:18:28.087","_LastEditorDisplayName":"Kevin Sheffield","_LastEditorUserId":590,"_OwnerUserId":590,"_PostTypeId":1,"_Score":4,"_Tags":"<community-server>","_Title":"Telligent's Community Server","_ViewCount":2432}
# ```
#
# ### `zcat data/stackoverflow/sample/Posts.100K.Questions.jsonl.gz | head -3 | jq -r ._Body`
#
# ```html
# <p>My dream IDE does full code hints, explains and completes PHP, Javascript, HTML and CSS. I know it exists!</p>
#
# <p>so far, <a href="http://www.zend.com/en/products/studio/features" rel="noreferrer">Zend studio 6</a>, under the Eclipse IDE does a great job at hinting PHP, some Javascript and HTML, any way I can expand this?</p>
#
# <p>edit: a bit more information: right now, using zend-6 under eclipse, i type in</p>
#
# <pre><code>&lt;?php
# p //(a single letter "p")
# </code></pre>
#
# <p>and I get a hint tooltip with all the available php functions that begin with "p" (phpinfo(), parse_ini_file(), parse_str(), etc...), each with its own explanation: phpinfo()->"outputs lots of PHP information", the same applies for regular HTML (no explanations however).</p>
#
# <p>However, I get nothing when I do:</p>
#
# <pre><code>&lt;style&gt;
# b /* (a single letter "b") */
# </code></pre>
#
# <p>I'd love it if I could get, from that "b" suggestions for "border", "bottom", etc. The same applies for Javascript.</p>
#
# <p>Any ideas?</p>
#
# <p>What is the Java equivalent of PHP's <code>$_POST</code>? After searching the web for an hour, I'm still nowhere closer.</p>
#
# <p>The company I work for is wanting to add blog functionality to our website and they were looking to spend an awful amount of money to have some crap being built on top of a CMS they purchased (sitecore).  I pointed them to Telligent's Community Server and  we had a sales like meeting today to get the Marketing folks on board.
# My question is if anyone has had issues working with Community Server, skinning it and extending it?<br />
# I wanted to explain a bit why I am thinking Community Server, the company is wanting multiple blogs with multiple authors.  I want to be out of the admin part of this as much as possible and didn't think there were too many engines that having multiple blogs didn't mean db work.  I also like the other functionality that Community Server provides and think the company will find it useful, particularly the media section as right now we have some really shotty way of dealing with whitepapers and stuff.</p>
#
# <p>edit: We are actually using the Sitecore blog module for a single blog on our intranet (which is actually what the CMS is serving).  Some reasoning for why I don't like it for our public site are they are on different servers, it doesn't support multiple authors, there is no built in syndication, it is a little flimsy feeling to me from looking at the source and I personally think the other features of Community Server make its price tag worth it.</p>
#
# <p>another edit: Need to stick to .net software that run on sql server in my company's case, but I don't mind seeing recommendations for others.  ExpressionEngine looks promising, will try it out on my personal box.</p>
# ```
#
# ## `SampleIds.100K.Questions.jsonl.gz`:
#
# ```json
# {"_SId":5264}
# {"_SId":6512}
# {"_SId":10190}
# ```
#
# ## `Users.100K.Questions.jsonl.gz`:
#
# ```json
# {"_AboutMe":"<p>Solution Architect on the Parature team at Microsoft based in Washington, DC.<br/>\n<br/>\nCoder for 25 years, .Net developer since 2001.<br/>\n<br/>\nTwitter: @justcallme98<br />\n<br />\nXbox Live Gamertag: ExitNinetyEight</p>\n","_AccountId":26,"_CreationDate":"2008-08-01T12:43:07.713","_DisplayName":"Greg Hurlman","_DownVotes":212,"_Id":35,"_LastAccessDate":"2019-02-26T05:28:49.427","_Location":"Washington, DC","_Reputation":15632,"_UpVotes":452,"_Views":1522,"_WebsiteUrl":"http://greghurlman.com"}
# {"_AboutMe":"<p>I'm currently studying computer engineering at the University of Michigan. My interests include: machine learning, data mining, hardware design, investing, and music.</p>\n","_AccountId":29,"_CreationDate":"2008-08-01T12:44:28.833","_DisplayName":"blcArmadillo","_DownVotes":0,"_Id":38,"_LastAccessDate":"2015-07-30T20:40:27.617","_Location":"Detroit, MI","_Reputation":2882,"_UpVotes":74,"_Views":558,"_WebsiteUrl":"http://www.ianburris.com"}
# {"_AboutMe":"<p>I like data visualization, music, Python, and scientific programming.\nSee what I'm up to on:</p>\n\n<ul>\n<li><a href=\"http://twitter.com/#!/jsundram\" rel=\"nofollow\">Twitter</a></li>\n<li><a href=\"http://runningwithdata.com\" rel=\"nofollow\">My blog</a></li>\n<li><a href=\"https://github.com/jsundram/\" rel=\"nofollow\">Github</a></li>\n<li><a href=\"http://about.me/jsundram\" rel=\"nofollow\">About.me</a></li>\n</ul>\n","_AccountId":1950,"_CreationDate":"2008-08-24T14:37:22.773","_DisplayName":"Jason Sundram","_DownVotes":17,"_Id":2683,"_LastAccessDate":"2019-02-13T17:59:40.070","_Location":"San Francisco, CA","_Reputation":5911,"_UpVotes":2148,"_Views":2056,"_WebsiteUrl":"http://runningwithdata.com"}
# ```
#
# ## `Votes.100K.Questions.jsonl.gz`:
#
# ```json
# {"_CreationDate":"2008-08-07T00:00:00.000","_Id":11203,"_PostId":5264,"_VoteTypeId":2}
# {"_CreationDate":"2008-08-09T00:00:00.000","_Id":13284,"_PostId":6515,"_VoteTypeId":2}
# {"_CreationDate":"2008-08-09T00:00:00.000","_Id":13352,"_PostId":6512,"_VoteTypeId":2}
# ```

# %% [markdown]
# ## Create Documents of All Values Per Question
#
# Combine all documents into something that can be served on a web page.

# %%
import sys, os, re
from pyspark.sql import SparkSession
from frozendict import frozendict

spark = SparkSession.builder.appName('Deep Products - Convert XML to Parquet').getOrCreate()
sc = spark.sparkContext

# %%
posts_df = spark.read.json('data/stackoverflow/sample/Posts.100K.Questions.jsonl.gz').alias('Posts')
posts_df.limit(3).toPandas()
# Out:
#    _AcceptedAnswerId  _AnswerCount  \
# 0               4877             2
# 1               5224             5
# 2               5462             8
#
#                                                _Body              _ClosedDate  \
# 0  <p>My dream IDE does full code hints, explains...                     None
# 1  <p>What is the Java equivalent of PHP's <code>...                     None
# 2  <p>The company I work for is wanting to add bl...  2012-11-16T12:21:26.777
#
#    _CommentCount _CommunityOwnedDate            _CreationDate  _FavoriteCount  \
# 0              0                None  2008-08-07T15:12:10.530             NaN
# 1              0                None  2008-08-07T19:39:31.240            10.0
# 2              0                None  2008-08-07T23:00:30.053             NaN
#
#     _Id        _LastActivityDate  ... _LastEditorDisplayName  \
# 0  4839  2013-02-12T11:55:21.800  ...       mauriciopastrana
# 1  5222  2018-04-19T13:12:43.453  ...           Stu Thompson
# ...

# %%
comments_df = spark.read.json('data/stackoverflow/sample/Comments.100K.Questions.jsonl.gz').alias('Comments')
comments_df.limit(3).toPandas()
# Out:
#              _CreationDate  _Id  _PostId  _Score  \
# 0  2008-09-07T00:18:11.643   61    47960       2
# 1  2008-09-07T00:37:17.870   63    47960       0
# 2  2008-09-07T23:09:03.410  193    47177       0
#
#                                                _Text _UserDisplayName  _UserId
# 0  You're really going to have to be more specifi...             None     2658
# 1  Have you even used any code snippets?\nThere i...             None     4035
# 2  To clarify, the sigar api gets you system info...             None      828

# %% [markdown]
# ## Compose into Single Giant Record
#
# ### Add a List of Comments to Posts

# %%
from frozendict import frozendict
import json

print('Posts count: {:,}'.format(posts_df.count()))
print('Comments count: {:,}'.format(comments_df.count()))

print('Non null posts count: {:,}'.format(posts_df.filter(posts_df._Id.isNotNull()).count()))
print('Non null comments count: {:,}'.format(comments_df.filter(comments_df._PostId.isNotNull()).count()))

print([x['_Id'] for x in posts_df.orderBy('_Id').take(10)])
print([x['_PostId'] for x in comments_df.orderBy('_PostId').take(10)])

post_comments = posts_df.join(comments_df, posts_df._Id == comments_df._PostId)
print('Post comments count: {:,}'.format(post_comments.count()))

comment_columns = [col for col in comments_df.columns]
post_columns = [col for col in posts_df.columns]

post_comment_dicts = \
    post_comments.rdd.map(
    lambda t: (
        frozendict({col:t[col] for col in post_columns}), 
        [{col:t[col] for col in comment_columns}]
    )
)
print('Post comments dict count: {:,}'.format(post_comment_dicts.count()))


def compose_dict(x):
    """Compose a final dictionary of a record with the Post fields present and the Comment records under 
       the 'Comments' key"""
    post = dict(x[0])
    comments = sorted(x[1], key=lambda y: y['_CreationDate'])
    post.update({'Comments': comments})
    return post

combined_docs = post_comment_dicts.reduceByKey(lambda a, b: a + b).map(compose_dict)
print('Combined docs count: {:,}'.format(combined_docs.count()))

os.system('rm -rf data/stackoverflow/sample/combined/Posts.Comments.jsonl.gz')
combined_docs.map(lambda x: json.dumps(x)).coalesce(1).saveAsTextFile(
    path='data/stackoverflow/sample/combined/Posts.Comments.jsonl.gz',
    compressionCodecClass="org.apache.hadoop.io.compress.GzipCodec"
)
# Out:
# Posts count: 276,788
# Comments count: 435,801
# Non null posts count: 276,788
# Non null comments count: 435,801
# [4839, 4852, 4877, 5222, 5224, 5227, 5460, 5462, 5465, 5492]
# [5273, 5273, 5273, 5273, 6515, 6572, 10190, 10194, 10282, 12820]
# Post comments count: 3,221
# Post comments dict count: 3,221
# Combined docs count: 990

# %% [markdown]
# ### Add Users and Votes to Posts

# %%
print('Original docs: {:,}'.format(combined_docs.count()))
print('Docs with _OwnerUserId: {:,}'.format(
    combined_docs.filter(lambda x: '_OwnerUserId' in x and x['_OwnerUserId'] is not None).count())
)

filtered_docs = combined_docs.filter(lambda x: '_OwnerUserId' in x and x['_OwnerUserId'] is not None)
print('Step 1 docs: {:,}'.format(filtered_docs.count()))

joinable_docs = filtered_docs.map(lambda x: (x['_OwnerUserId'], x))\
                             .filter(lambda x: x[0] is not None)
print('Step 2 docs: {:,}'.format(joinable_docs.count()))

users_df = spark.read.json('data/stackoverflow/sample/Users.100K.Questions.jsonl.gz').rdd\
                .filter(lambda x: x['_Id'] is not None)
users_df.count()
# Out:
# Original docs: 990
# 981
# Step 1 docs: 981
# Step 1 docs: 981

# %%
def choose_list(x):
    if not x or len(x) < 1:
        print("E")
        return []
    return x

users_docs = joinable_docs.leftOuterJoin(
    users_df.filter(lambda x: '_Id' in x and x['_Id'] is not None).map(lambda x: (x['_Id'], x))
)
print('Original docs: {:,}'.format(users_docs.count()))
users_docs.filter(lambda x: len(x[1][0]) < 1).count()
.filter(
    lambda x: len(x) > 1 and x[0] is not None and len(x[1]) > 0 and len(x[1][0]) > 0 and len(x[1][1]) > 0)\
  .map(lambda x: ([y for y in x[1][0]][0], choose_list(x[1])))

users_docs.count()

def update_owner(x):
    x[0].update({'_Owner': sorted([y for y in x[1]], key=lambda z: z['_OwnerUserId'])})
    return x[0]

updated_users_docs = users_docs.map(update_owner)

print(users_docs.count())
users_docs.first()
# Out:
# Original docs: 981

# %% [markdown]
# ### Nest Answer Posts to Question Posts

# %%
votes_df = spark.read.json('data/stackoverflow/sample/Votes.100K.Questions.jsonl.gz')
joinable_votes = votes_df.rdd.filter(lambda x: '_PostId' in x and x['_PostId'] is not None).map(lambda x: (x['_PostId'], x))
joinable_votes.count()
# Out:
# 963731
